# %% [markdown]
# ### <p style="color:Darkred;">API OPENLIBRA</p>
#
# ### <p style="color:DarkBlue;">INTRODUCCIÓN</p>
# OpenLibra dispone de un ligero servicio web con el que es posible acceder de forma remota a la mayoría de los datos de su catálogo bibliográfico. Esta primera versión del API facilita clasificar y buscar libros según un criterio concreto o facilitar la lectura de documentos directamente online sin navegador.
# ### <p style="color:DarkBlue;">JAVASCRIPT / JSONP</p>
# El acceso a la información se realiza mediante una petición AJAX (Javascript) a los servidores de OpenLibra los cuales devuelven un objeto JSON con los datos encontrados.Un ejemplo típico de petición utilizando la citada jQuery es el siguiente:
#
# $.getJSON( 'https://www.etnassoft.com/api/v1/get/?id=589&callback=?', function ( results ) { console.log( 'Search Result(s): ', results ); } );
#
# La petición anterior buscará en cualquier caso el libro con el ID número 589 en la base de datos. El sistema devolverá un objeto JSON

# %% [markdown]
# ![openlibra](https://otroespacioblog.files.wordpress.com/2012/06/3f792-openlibra-logo.png)
#
# # <p style="color:DarkBlue;">PARÁMETROS</p>
#
# - **id**: El id del libro (?id=505)
#
# - **book_title** : El título del libro (?book_title=javascript)
#
# - **book_author**: El autor del libro (?book_author=paenza)
#
# - **publisher** : La editorial del libro (?publisher=UOC)
#
# - **lang** : Lenguaje del libro (?lang=english)
#
# - **keyword** : Palabra clave del libro (?keyword=java)
#
# - **category** : Categoría del libro (RELACIÓN DE CATEGORÍAS) (?category=programacion)
#
# - **num_items** : Número de libros a mostrar (?num_items=25)
#
# - **criteria** : Criterio para crear una colección (El criterio puede ser:most_viewed - Los libros más vistos ,most_commented - Los libros más comentados)
#
# - **publisher_date** : La fecha de publicación del libro (?publisher_date=2011)
#
#
#
# # <p style="color:DarkBlue;">EJEMPLOS DE USO</p>
#
# - **Recuperar un libro mediante su ID:**
#
# https://www.etnassoft.com/api/v1/get/?id=589
#
# - **Recuperar los libros más vistos de la categoria programación**
#
# https://www.etnassoft.com/api/v1/get/?category=libros_programacion&criteria=most_viewed
#
# - **Recuperar los libros más recientes etiquetados como HTML, CSS o Javascript**
#
# https://www.etnassoft.com/api/v1/get/?any_tags=[html,css,javascript]&order=newest
#
# - **Recuperar los libros que tengan en algún campo el término Javascript y se hayan publicado durante 2011**
#
# https://www.etnassoft.com/api/v1/get/?keyword=javascript&publisher_date=2011
#
# - **Recuperar todos los libros escritos por Adrián Paenza**
#
# https://www.etnassoft.com/api/v1/get/?book_author=adrian_paenza

# %%
import pandas as pd
import requests
import urllib.request
import json
from urllib.request import urlopen

# %%
verificar=requests.get("https://openlibra.com/es/")
print(verificar)
# Out:
# <Response [200]>

# %% [markdown]
# # <p style="color:Darkgreen;">Extrayendo los libros del autor Alonso Jimenez</p>

# %%
url='https://www.etnassoft.com/api/v1/get/?book_author=alonso_jimenez&callback=?'
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())

df=pd.DataFrame(info)
print(list(df.columns))
df_ajimenez=df[['ID','title','content_short','publisher','publisher_date','pages','language']]
df_ajimenez
# Out:
# ['ID', 'title', 'author', 'content', 'content_short', 'publisher', 'publisher_date', 'pages', 'language', 'url_details', 'url_download', 'cover', 'thumbnail', 'num_comments', 'categories', 'tags']
#       ID                                              title  \
# 0  15148    Temas de Programación funcional (curso 2012–13)
# 1  15150  Introducción a la demostracción asistida por o...
# 2  14240  Piensa en Haskell (Ejercicios de programación ...
# 3  10297       Introducción al cálculo simbólico con Maxima
# 4   5012                Temas de Lógica Informática 2010-11
# 5   2370           Ejercicios de Informática de Matemáticas
# 6   7258              Temas de "Programación lógica e I.A."
# 7   6159                                  Lógica en Haskell
# 8   5010           Ejercicios de Lógica Informática 2012-13
# 9   5015       Soluciones de Exámenes de Lógica Informática
#
#                                        content_short               publisher  \
# 0  Desde el inicio (en el curso 2009&ndash;10) de...  Universidad de Sevilla
# 1  Este libro es una recopilaci&oacute;n de los t...  Universidad de Sevilla
# 2  Este libro es una introducci&oacute;n a la pro...  Universidad de Sevilla
# 3  El sistema de &aacute;lgebra computacional Max...  Universidad de Sevilla
# 4  La l&oacute;gica computacional es la misma l&o...  Universidad de Sevilla
# 5  Este libro es una recopilaci&oacute;n de las s...  Universidad de Sevilla
# 6  La programaci&oacute;n l&oacute;gica es un tip...  Universidad de Sevilla
# 7  Haskell (h&aelig;skəl) es un lenguaje de progr...  Universidad de Sevilla
# 8  La l&oacute;gica computacional es la misma l&o...  Universidad de Sevilla
# 9  La l&oacute;gica computacional es la misma l&o...  Universidad de Sevilla
#
#   publisher_date pages language
# 0           2012   321  spanish
# 1           2013   283  spanish
# 2           2012   428  spanish
# 3           2010   149  spanish
# 4           2010   138  spanish
# 5           2012   162  spanish
# 6           2013   262  spanish
# 7           2008   138  spanish
# 8           2012   100  spanish
# 9           2004    69  spanish

# %%
df_ajimenez=df[['cover', 'thumbnail', 'num_comments', 'categories', 'tags']]
df_ajimenez
# Out:
#                                                cover  \
# 0  http://collection.openlibra.com.s3.amazonaws.c...
# 1  http://collection.openlibra.com.s3.amazonaws.c...
# 2  http://collection.openlibra.com.s3.amazonaws.c...
# 3  http://collection.openlibra.com.s3.amazonaws.c...
# 4  http://collection.openlibra.com.s3.amazonaws.c...
# 5  http://collection.openlibra.com.s3.amazonaws.c...
# 6  http://collection.openlibra.com.s3.amazonaws.c...
# 7  http://collection.openlibra.com.s3.amazonaws.c...
# 8  http://collection.openlibra.com.s3.amazonaws.c...
# 9  http://collection.openlibra.com.s3.amazonaws.c...
#
#                                            thumbnail num_comments  \
# 0  http://collection.openlibra.com.s3.amazonaws.c...            0
# 1  http://collection.openlibra.com.s3.amazonaws.c...            0
# 2  http://collection.openlibra.com.s3.amazonaws.c...            0
# 3  http://collection.openlibra.com.s3.amazonaws.c...            0
# 4  http://collection.openlibra.com.s3.amazonaws.c...            0
# 5  http://collection.openlibra.com.s3.amazonaws.c...            0
# 6  http://collection.openlibra.com.s3.amazonaws.c...            0
# 7  http://collection.openlibra.com.s3.amazonaws.c...            0
# 8  http://collection.openlibra.com.s3.amazonaws.c...            0
# 9  http://collection.openlibra.com.s3.amazonaws.c...            0
#
#                                           categories  \
# 0  [{'category_id': 417, 'name': 'Haskell', 'nice...
# 1  [{'category_id': 224, 'name': 'Otros Lenguajes...
# 2  [{'category_id': 417, 'name': 'Haskell', 'nice...
# 3  [{'category_id': 206, 'name': 'Ciencia', 'nice...
# 4  [{'category_id': 264, 'name': 'Algoritmos', 'n...
# 5  [{'category_id': 264, 'name': 'Algoritmos', 'n...
# 6  [{'category_id': 220, 'name': 'Programación', ...
# 7  [{'category_id': 264, 'name': 'Algoritmos', 'n...
# 8  [{'category_id': 264, 'name': 'Algoritmos', 'n...
# 9  [{'category_id': 264, 'name': 'Algoritmos', 'n...
#
#                                                 tags
# 0  [{'tag_id': 3004, 'name': 'Haskell', 'nicename...
# 1  [{'tag_id': 784, 'name': 'cuaderno de ejercici...
# 2  [{'tag_id': 828, 'name': 'algoritmia', 'nicena...
# 3  [{'tag_id': 919, 'name': 'álgebra', 'nicename'...
# 4  [{'tag_id': 828, 'name': 'algoritmia', 'nicena...
# 5  [{'tag_id': 784, 'name': 'cuaderno de ejercici...
# 6  [{'tag_id': 692, 'name': 'AI', 'nicename': 'ai...
# 7  [{'tag_id': 784, 'name': 'cuaderno de ejercici...
# 8  [{'tag_id': 828, 'name': 'algoritmia', 'nicena...
# 9  [{'tag_id': 828, 'name': 'algoritmia', 'nicena...

# %% [markdown]
# # <p style="color:Darkgreen;">Extrayendo información de un libro atraves de su ID</p>

# %%
url="https://www.etnassoft.com/api/v1/get/?id=5010&callback=?"
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())
dic_libro=info[0]
print(dic_libro["ID"])
print(dic_libro["title"])
print(dic_libro["author"])
# Out:
# 5010
# Ejercicios de Lógica Informática 2012-13
# José A. Alonso Jiménez

# %%
url="https://www.etnassoft.com/api/v1/get/?id=5012&callback=?"
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())
dic_libro=info[0]
print(dic_libro["ID"])
print(dic_libro["title"])
print(dic_libro["author"])
# Out:
# 5012
# Temas de Lógica Informática 2010-11
# José A. Alonso Jiménez

# %% [markdown]
# # <p style="color:Darkgreen;">Extrayendo todos los libros del autor Alonso Jimenez</p>

# %%
url='https://www.etnassoft.com/api/v1/get/?book_author=alonso_jimenez&callback=?&num_items=15'
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())

df=pd.DataFrame(info)
print(list(df.columns))
df_ajimenez=df[['ID','title','content_short','publisher','publisher_date','pages','language']]
df_ajimenez
# Out:
# ['ID', 'title', 'author', 'content', 'content_short', 'publisher', 'publisher_date', 'pages', 'language', 'url_details', 'url_download', 'cover', 'thumbnail', 'num_comments', 'categories', 'tags']
#        ID                                              title  \
# 0   15148    Temas de Programación funcional (curso 2012–13)
# 1   15150  Introducción a la demostracción asistida por o...
# 2   14240  Piensa en Haskell (Ejercicios de programación ...
# 3   10297       Introducción al cálculo simbólico con Maxima
# 4    5012                Temas de Lógica Informática 2010-11
# 5    2370           Ejercicios de Informática de Matemáticas
# 6    7258              Temas de "Programación lógica e I.A."
# 7    6159                                  Lógica en Haskell
# 8    5010           Ejercicios de Lógica Informática 2012-13
# 9    5015       Soluciones de Exámenes de Lógica Informática
# 10   2371                   Programación Funcional 2011-2012
# 11   1748                             Programación Funcional
# 12   1742  Ejercicios de programación declarativa con Prolog
# 13   1740   Introducción a la programación lógica con Prolog
# 14   1602   Ejercicios de programación funcional con Haskell
#
#                                         content_short               publisher  \
# 0   Desde el inicio (en el curso 2009&ndash;10) de...  Universidad de Sevilla
# 1   Este libro es una recopilaci&oacute;n de los t...  Universidad de Sevilla
# 2   Este libro es una introducci&oacute;n a la pro...  Universidad de Sevilla
# 3   El sistema de &aacute;lgebra computacional Max...  Universidad de Sevilla
# 4   La l&oacute;gica computacional es la misma l&o...  Universidad de Sevilla
# 5   Este libro es una recopilaci&oacute;n de las s...  Universidad de Sevilla
# 6   La programaci&oacute;n l&oacute;gica es un tip...  Universidad de Sevilla
# 7   Haskell (h&aelig;skəl) es un lenguaje de progr...  Universidad de Sevilla
# 8   La l&oacute;gica computacional es la misma l&o...  Universidad de Sevilla
# 9   La l&oacute;gica computacional es la misma l&o...  Universidad de Sevilla
# 10  En ciencias de la computaci&oacute;n, la progr...  Universidad de Sevilla
# 11  En ciencias de la computaci&oacute;n, la progr...             Autoedición
# 12  La Programaci&oacute;n Declarativa, en contrap...  Universidad de Sevilla
# 13  El Prolog (o PROLOG), proveniente del franc&ea...  Universidad de Sevilla
# 14  Las caracter&iacute;sticas m&aacute;s interesa...  Universidad de Sevilla
#
#    publisher_date pages language
# 0            2012   321  spanish
# 1            2013   283  spanish
# 2            2012   428  spanish
# 3            2010   149  spanish
# 4            2010   138  spanish
# 5            2012   162  spanish
# 6            2013   262  spanish
# 7            2008   138  spanish
# 8            2012   100  spanish
# 9            2004    69  spanish
# 10           2011   339  spanish
# 11           2010   339  spanish
# 12           2007   124  spanish
# 13           2006    33  spanish
# 14           2007   266  spanish

# %% [markdown]
# # <p style="color:Darkgreen;">Extrayendo los libros del autor Juan Merodio</p>

# %%
url='https://www.etnassoft.com/api/v1/get/?book_author=juan_merodio&callback=?'
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())

df=pd.DataFrame(info)
print(list(df.columns))
df_juan=df[['ID','title','content_short','publisher','publisher_date','pages','language']]
df_juan
# Out:
# ['ID', 'title', 'author', 'content', 'content_short', 'publisher', 'publisher_date', 'pages', 'language', 'url_details', 'url_download', 'cover', 'thumbnail', 'num_comments', 'categories', 'tags']
#      ID                                 title  \
# 0  2536               Ideas de Marketing 2011
# 1  1598  365 Días (y noches) de Marketing 2.0
# 2  1572           Marketing en Redes Sociales
#
#                                        content_short    publisher  \
# 0  Juan Merodio, nacido en 1980, es uno de los pr...  Autoedición
# 1  Seg&uacute;n las palabras de su autor: \r\n\r\...  Autoedición
# 2  &iquest;C&oacute;mo definir&iacute;as el Socia...  Autoedición
#
#   publisher_date pages language
# 0           2011   381  spanish
# 1           2010   460  spanish
# 2           2010   107  spanish

# %%
url="https://www.etnassoft.com/api/v1/get/?id=1598&callback=?"
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())
dic_libro=info[0]
print(dic_libro["ID"])
print(dic_libro["title"])
print(dic_libro["author"])
# Out:
# 1598
# 365 Días (y noches) de Marketing 2.0
# Juán Merodio

# %% [markdown]
# # <p style="color:Darkgreen;">Extrayendo los libros de la categoría programación con mayores visitas</p>

# %%
url='https://www.etnassoft.com/api/v1/get/?category=libros_programacion&criteria=most_viewed'
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())

df=pd.DataFrame(info)
print(list(df.columns))
df_programacion=df[['ID','title','content_short','publisher','publisher_date','pages','language']]
df_programacion
# Out:
# ['ID', 'title', 'author', 'content', 'content_short', 'publisher', 'publisher_date', 'pages', 'language', 'url_details', 'url_download', 'cover', 'thumbnail', 'num_comments', 'categories', 'tags']
#      ID                                              title  \
# 0  1471                                   POO y MVC en PHP
# 1   595  Desarrollo de aplicaciones iPhone e iPad para ...
# 2   853                                jQuery Fundamentals
# 3  3752                                Introducción a .NET
# 4  1600  Practical Artifical Intelligence Programming w...
# 5  9505  Desarrollo fácil y paso a paso de aplicaciones...
# 6   897                        A byte of VIM (for VIM v.7)
# 7   772                      Silverlight for Windows Phone
# 8  1870                              Fundamentos de jQuery
# 9  2295  Diseño de una Metodología Ágil de Desarrollo d...
#
#                                        content_short    publisher  \
# 0  &lt;strong&gt;El paradigma de la Programaci&oa...  Autoedición
# 1  Quieres aprender c&oacute;mo programar para el...       Apress
# 2  jQuery es una biblioteca o framework de JavaSc...  Autoedición
# 3  .NET es el entorno de ejecuci&oacute;n en el q...          UOC
# 4  Este libro ha sido escrito para aquellos desar...  Autoedición
# 5  Android es actualmente (Mayo de 2013) el siste...  Autoedición
# 6  Vim (del ingl&eacute;s Vi IMproved) es una ver...  Autoedición
# 7  Microsoft Silverlight es una estructura para a...    Microsoft
# 8  jQuery se est&aacute; convirtiendo r&aacute;pi...  Autoedición
# 9  Esta t&eacute;sis tiene como prop&oacute;sito ...        Fiuba
#
#   publisher_date pages language
# 0           2011    66  spanish
# 1           2011   297  spanish
# 2           2010    72  english
# 3           2009   102  spanish
# 4           2008   222  english
# 5           2013   104  spanish
# 6           2010    89  english
# 7           2011   157  english
# 8           2011   112  spanish
# 9           2004   199  spanish

# %% [markdown]
# # <p style="color:Darkgreen;">Extrayendo las categorías</p>

# %%
url='https://www.etnassoft.com/api/v1/get/?get_categories'
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())

df=pd.DataFrame(info)
print(list(df.columns))
df_categorias=df[['name','nicename',]]
df_categorias
# Out:
# ['category_id', 'name', 'nicename']
#                       name                       nicename
# 0                  Ajedrez                        ajedrez
# 1      Arte - Bellas Artes              arte-bellas-artes
# 2         Aspectos Legales       libros_aspecotos_legales
# 3           Bases de datos                 bases_de_datos
# 4                  Ciencia                        ciencia
# 5                     Cine                           cine
# 6                   Cómics                         comics
# 7     Control de Versiones           control_de_versiones
# 8           Desarrollo Web                 desarrollo_web
# 9              Diseño / 3D                      diseno_3d
# 10               Educación                      educacion
# 11             Electrónica                    electronica
# 12       Ensayos / Novelas              ensayos_y_novelas
# 13               Filosofía                      filosofia
# 14     Geografía / Turismo              geografia-turismo
# 15                Historia                       historia
# 16                 Idiomas                        idiomas
# 17             Información                    informacion
# 18    Marketing / Business           marketing_y_business
# 19     Metodologías Ágiles            metodologias_agiles
# 20              Multimedia                     multimedia
# 21                  Música                         musica
# 22            Programación            libros_programacion
# 23       Redes y Sys Admin              redes_y_sysadmins
# 24        Retroinformática               retroinformatica
# 25                Revistas                       revistas
# 26                Robótica                       robotica
# 27               SEO / SEM                      seo_y_sem
# 28        Software General               software-general
# 29          Software Libre          libros_software_libre
# 30       Textos Académicos              textos-academicos
# 31  Web 2.0 y Social Media  libros_web_2_0_y_social_media

# %% [markdown]
# # <p style="color:Darkgreen;">Extrayendo los libros de la categoría programación y de idioma español</p>

# %%
url='https://www.etnassoft.com/api/v1/get/?category=programacion&lang=spanish'
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
info=json.loads(responsehtml.decode())

df=pd.DataFrame(info)
print(list(df.columns))
df_programacion1=df[['ID','title','content_short','publisher','publisher_date','pages','language']]
df_programacion1
# Out:
# ['ID', 'title', 'author', 'content', 'content_short', 'publisher', 'publisher_date', 'pages', 'language', 'url_details', 'url_download', 'cover', 'thumbnail', 'num_comments', 'categories', 'tags']
#       ID                                              title  \
# 0  17025  Análisis Espacial con R: Usa R como un sistema...
# 1  16701                     Matemática discreta en Haskell
# 2  16659                                     Hello World #4
# 3  16644                           Trabajar con la Compu II
# 4  16532                    Tras instalar Debian 8 (Jessie)
# 5  16439                  Lógica de primer orden en Haskell
# 6  16547                                BITS de Ciencia #15
# 7  16506                Aprendiendo SIG con Juego de Tronos
# 8  16462       Guía para la Galaxia de Aplicaciones Móviles
# 9  16287  Fundamentos de Programación con el Lenguaje de...
#
#                                        content_short  \
# 0  R, una plataforma de an&aacute;lisis estad&iac...
# 1  El objetivo del trabajo es la implementaci&oac...
# 2  Join our panel of experts in issue 4 of Hello ...
# 3  Conectad@s, la revista consiste en la edici&oa...
# 4  Libro NO oficial, para su realizaci&oacute;n s...
# 5  La l&oacute;gica de primer orden o l&oacute;gi...
# 6  La Computaci&oacute;n es una disciplina que in...
# 7  Este libro recopila una serie de post con ejer...
# 8  Bienvenido al mundo del desarrollo m&oacute;vi...
# 9  En este manual se describen las caracter&iacut...
#
#                        publisher publisher_date pages language
# 0  European Scientific Institute           2013   151  spanish
# 1         Universidad de Sevilla           2017   124  spanish
# 2                    Autoedición           2018   100  spanish
# 3       Presidencia de la Nación           2013    36  spanish
# 4                    Autoedición           2015   117  spanish
# 5         Universidad de Sevilla           2017   130  spanish
# 6           Universidad de Chile           2017    82  spanish
# 7               Asociación gvSIG           2017    66  spanish
# 8                Enough Software           2016   309  spanish
# 9          Universidad de Málaga           2017   195  spanish

# %% [markdown]
# # <p style="color:Darkgreen;">Cantidad de libros que tiene un autor</p>

# %%
import requests

def obtener_cantidad_libros_autor(autor):
    url = f"https://www.etnassoft.com/api/v1/get/?book_author=juan_merodio&callback=?"
    response = requests.get(url)
    if response.status_code == 200:
        libros = response.json()
        cantidad_libros = len(libros)
        return cantidad_libros
    else:
        return None

autor = "Juan Merodio"
cantidad_libros = obtener_cantidad_libros_autor(autor)
if cantidad_libros is not None:
    print(f"El autor {autor} tiene {cantidad_libros} libros.")
else:
    print("No se encontraron libros del autor especificado.")
# Out:
# El autor Juan Merodio tiene 3 libros.

# %% [markdown]
# # <p style="color:Darkgreen;">Cantidad de libros que tiene la categoría programación</p>

# %%
import requests

def obtener_cantidad_libros_programacion():
    url = "https://www.etnassoft.com/api/v1/get/?category=libros_programacion&criteria=most_viewed"
    response = requests.get(url)
    if response.status_code == 200:
        libros = response.json()
        cantidad_libros = len(libros)
        return cantidad_libros
    else:
        return None

cantidad_libros_programacion = obtener_cantidad_libros_programacion()
if cantidad_libros_programacion is not None:
    print(f"La categoría 'programación' tiene {cantidad_libros_programacion} libros.")
else:
    print("No se encontraron libros en la categoría 'programación'.")
# Out:
# La categoría 'programación' tiene 10 libros.

# %%
import requests

def obtener_cantidad_libros_programacion():
    url = "https://www.etnassoft.com/api/v1/get/?category=libros_programacion&num_items=1150"
    response = requests.get(url)
    if response.status_code == 200:
        libros = response.json()
        cantidad_libros = len(libros)
        return cantidad_libros
    else:
        return None

cantidad_libros_programacion = obtener_cantidad_libros_programacion()
if cantidad_libros_programacion is not None:
    print(f"La categoría 'programación' tiene {cantidad_libros_programacion} libros.")
else:
    print("No se encontraron libros en la categoría 'programación'.")
# Out:
# La categoría 'programación' tiene 996 libros.

# %%
import requests

def obtener_cantidad_libros_autor(autor):
    url = f"https://www.etnassoft.com/api/v1/get/?book_author=jorge_sanchez&callback=?"
    response = requests.get(url)
    if response.status_code == 200:
        libros = response.json()
        cantidad_libros = len(libros)
        return cantidad_libros
    else:
        return None

autor = "Jorge sanchez"
cantidad_libros = obtener_cantidad_libros_autor(autor)
if cantidad_libros is not None:
    print(f"El autor {autor} tiene {cantidad_libros} libros.")
else:
    print("No se encontraron libros del autor especificado.")
# Out:
# El autor Jorge sanchez tiene 5 libros.

# %% [markdown]
# # <p style="color:Darkgreen;">Extraer los enlaces de las portadas de los libros de Alonso Jimenez</p>

# %%
def obtener_enlaces_portadas_autor(autor):
    url = f"https://www.etnassoft.com/api/v1/get/?book_author=alonso_jimenez&callback=?&num_items=15"
    response = requests.get(url)
    if response.status_code == 200:
        libros = response.json()
        enlaces_portadas = []
        for libro in libros:
            enlace_portada = libro['cover']
            enlaces_portadas.append(enlace_portada)
        return enlaces_portadas
    else:
        return None

autor = "jorge_sanchez"
enlaces_portadas = obtener_enlaces_portadas_autor(autor)
if enlaces_portadas is not None:
    for enlace in enlaces_portadas:
        print(enlace)
else:
    print("No se encontraron libros del autor especificado.")
# Out:
# http://collection.openlibra.com.s3.amazonaws.com/covers/2016/06/temas-de-programacion-funcional-OpenLibra-350x461.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2016/06/Introduccion-demostracion-asistida-ordenador-Isabelle-HOL-OpenLibra-350x461.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2015/10/Piensa-en-Haskell-OpenLibra-350x461.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2013/08/Introduccion-calculo-simbolico-Maxima-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2012/10/Temas-de-Logica-Informatica-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2012/02/ejercicios-Iogica-computacional-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2013/02/Temas-Programacion-Logica-IA-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2012/12/Logica-en-Haskell-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2012/10/Ejercicios-Logica-Informatica-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2012/10/Soluciones-de-examenes-de-logica-informatica-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2012/02/programacion-funcional-2012-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2011/09/Programacion-funcional-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2011/09/Ejercicios-Programacion-Declarativa-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2011/09/Introduccion-Programacion-Logica-Prolog-OpenLibra-350x459.gif
# http://collection.openlibra.com.s3.amazonaws.com/covers/2011/08/Ejercicios_programacion_funcional_Haskell_OpenLibra-350x459.gif
